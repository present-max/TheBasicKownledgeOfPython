# %%
import  pandas as pd

#构造DataFrame(表格)
df1=pd.DataFrame([
    {"姓名":"小明","语文":80,"数学":90,"英语":75},
    {"姓名":"小红","语文":75,"数学":85,"英语":90},
    {"姓名":"小刚","语文":60,"数学":70,"英语":80},
    {"姓名":"小丽","语文":90,"数学":80,"英语":85},
    {"姓名":"小华","语文":70,"数学":60,"英语":75}]
)
df2=pd.DataFrame({
    "姓名":["小明","小红","小刚","小丽","小华"],
    "语文":[80,75,60,90,70],
    "数学":[90,85,70,80,60],
    "英语":[75,90,80,85,75]
})
#获取列
print(df1.columns.tolist())
#获取行
print(df1.values.tolist())
#获取元素个数
print(df1.size)
# Out:
# ['姓名', '语文', '数学', '英语']
# [['小明', 80, 90, 75], ['小红', 75, 85, 90], ['小刚', 60, 70, 80], ['小丽', 90, 80, 85], ['小华', 70, 60, 75]]
# 20

# %%
#Series的创建
s1=pd.Series([1,2,3,4,5])
s2=pd.Series({1:10,2:20,3:30})
#print(s1)
#print(s2)
s3=df1["姓名"]
#print(s3)
#获取值
s3.values.tolist()
# Out:
# ['小明', '小红', '小刚', '小丽', '小华']

# %%
#读取数据
df=pd.read_csv("resourse/movie_top100.csv",usecols=["电影名","导演","上映时间","评分"])
df
#写入数据，index=False表示不写入行索引
df.to_csv("resourse/movie_top100_new.csv",index=False)
